# %% [markdown]
# <a href="https://colab.research.google.com/github/saipraveen333/Day5_ML/blob/main/Day_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv("/content/Car.csv")

# %%
data.head()
# Out:
#          Price  Cylinder  Liter  Doors  Cruise  Sound  Leather  Mileage1
# 0  17314.10313         6    3.1      4       1      1        1  0.158716
# 1  17542.03608         6    3.1      4       1      1        0  0.176952
# 2  16218.84786         6    3.1      4       1      1        0  0.257976
# 3  16336.91314         6    3.1      4       1      0        0  0.320744
# 4  16339.17032         6    3.1      4       1      0        1  0.390375

# %%
sns.boxplot(y = data['Price'])

# %%
data['Make'].value_counts()
# Out:
# Chevrolet    320
# Pontiac      150
# SAAB         114
# Buick         80
# Cadillac      80
# Saturn        60
# Name: Make, dtype: int64

# %%
sns.countplot(data['Make'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(data['Make'])
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
from sklearn.preprocessing import MinMaxScaler
cat_col=['Trim','Make','Model','Type']
df_2 = pd.get_dummies(data[cat_col], drop_first = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-69-8a713ed4817d> in <module>()
#       1 from sklearn.preprocessing import MinMaxScaler
#       2 cat_col=['Trim','Make','Model','Type']
# ----> 3 df_2 = pd.get_dummies(data[cat_col], drop_first = True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2910             if is_iterator(key):
#    2911                 key = list(key)
# -> 2912             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2913
#    2914         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1296             if missing == len(indexer):
#    1297                 axis_name = self.obj._get_axis_name(axis)
# -> 1298                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1299
#    1300             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['Trim', 'Make', 'Model', 'Type'], dtype='object')] are in the [columns]"

# %%
scale=MinMaxScaler()
data['Mileage1']=scale.fit_transform(data[['Mileage']])
data
# Out:
#            Price   Mileage    Make     Model  ... Cruise Sound  Leather  Mileage1
# 0    17314.10313  0.158716   Buick   Century  ...      1     1        1  0.158716
# 1    17542.03608  0.176952   Buick   Century  ...      1     1        0  0.176952
# 2    16218.84786  0.257976   Buick   Century  ...      1     1        0  0.257976
# 3    16336.91314  0.320744   Buick   Century  ...      1     0        0  0.320744
# 4    16339.17032  0.390375   Buick   Century  ...      1     0        1  0.390375
# ..           ...       ...     ...       ...  ...    ...   ...      ...       ...
# 799  16507.07027  0.318489  Saturn  L Series  ...      1     0        0  0.318489
# 800  16175.95760  0.375671  Saturn  L Series  ...      1     1        0  0.375671
# 801  15731.13290  0.403384  Saturn  L Series  ...      1     1        0  0.403384
# 802  15118.89323  0.513018  Saturn  L Series  ...      1     1        0  0.513018
# 803  13585.63680  0.706211  Saturn  L Series  ...      1     0        0  0.706211
#
# [804 rows x 13 columns]

# %% [markdown]
# data.drop(['Type'],axis=1,inplace=True)
# data
# df_2

# %%
data
# Out:
#            Price  Cylinder  Liter  Doors  Cruise  Sound  Leather  Mileage1
# 0    17314.10313         6    3.1      4       1      1        1  0.158716
# 1    17542.03608         6    3.1      4       1      1        0  0.176952
# 2    16218.84786         6    3.1      4       1      1        0  0.257976
# 3    16336.91314         6    3.1      4       1      0        0  0.320744
# 4    16339.17032         6    3.1      4       1      0        1  0.390375
# ..           ...       ...    ...    ...     ...    ...      ...       ...
# 799  16507.07027         6    3.0      4       1      0        0  0.318489
# 800  16175.95760         6    3.0      4       1      1        0  0.375671
# 801  15731.13290         6    3.0      4       1      1        0  0.403384
# 802  15118.89323         6    3.0      4       1      1        0  0.513018
# 803  13585.63680         6    3.0      4       1      0        0  0.706211
#
# [804 rows x 8 columns]

# %%
data_new=pd.concat([data,df_2],axis=1)
data_new
# Out:
#            Price  Cylinder  Liter  ...  Type_Hatchback  Type_Sedan  Type_Wagon
# 0    17314.10313         6    3.1  ...               0           1           0
# 1    17542.03608         6    3.1  ...               0           1           0
# 2    16218.84786         6    3.1  ...               0           1           0
# 3    16336.91314         6    3.1  ...               0           1           0
# 4    16339.17032         6    3.1  ...               0           1           0
# ..           ...       ...    ...  ...             ...         ...         ...
# 799  16507.07027         6    3.0  ...               0           1           0
# 800  16175.95760         6    3.0  ...               0           1           0
# 801  15731.13290         6    3.0  ...               0           1           0
# 802  15118.89323         6    3.0  ...               0           1           0
# 803  13585.63680         6    3.0  ...               0           1           0
#
# [804 rows x 94 columns]

# %%
x=data_new[['Mileage1']]
y=data_new[['Price']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)

# %%
df_2
# Out:
#      Trim_Aero Conv 2D  Trim_Aero Sedan 4D  ...  Type_Sedan  Type_Wagon
# 0                    0                   0  ...           1           0
# 1                    0                   0  ...           1           0
# 2                    0                   0  ...           1           0
# 3                    0                   0  ...           1           0
# 4                    0                   0  ...           1           0
# ..                 ...                 ...  ...         ...         ...
# 799                  0                   0  ...           1           0
# 800                  0                   0  ...           1           0
# 801                  0                   0  ...           1           0
# 802                  0                   0  ...           1           0
# 803                  0                   0  ...           1           0
#
# [804 rows x 86 columns]

# %%
x_train.shape
# Out:
# (603, 1)

# %%
y_train.shape
# Out:
# (603, 1)

# %%
x_test.shape
# Out:
# (201, 1)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

lr.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr.predict(x_test)
# Out:
# array([[22504.76865956],
#        [20607.06358155],
#        [20760.66144243],
#        [20396.48021292],
#        [21959.11050537],
#        [22469.17463472],
#        [21539.17114828],
#        [20572.8722769 ],
#        [20505.71704777],
#        [20164.85604143],
#        [20206.41162708],
#        [21164.29417731],
#        [21626.31514012],
#        [21174.98991876],
#        [24873.78772164],
#        [22471.10337498],
#        [21453.07919657],
#        [21262.48459066],
#        [21730.81779433],
#        [21770.79531977],
#        [20496.42402651],
#        [20011.08284052],
#        [22479.3443561 ],
#        [21982.78140859],
#        [20135.74959747],
#        [22561.22814723],
#        [22035.38341574],
#        [18615.55159079],
#        [18779.14383303],
#        [21038.22470017],
#        [22866.31978871],
#        [21753.43665741],
#        [23199.465834  ],
#        [22521.95198189],
#        [19816.63075409],
#        [21093.80748773],
#        [23732.85018652],
#        [20234.29069087],
#        [23533.83925947],
#        [23011.1506484 ],
#        [20805.19780849],
#        [24820.48435439],
#        [22575.43068916],
#        [21835.14510852],
#        [21876.52535414],
#        [22160.05017269],
#        [23308.00130876],
#        [20256.38353387],
#        [23899.77388922],
#        [22377.1211222 ],
#        [20615.12922265],
#        [20502.73626737],
#        [20590.23093926],
#        [19080.37799399],
#        [22212.82751987],
#        [19784.3681897 ],
#        [22350.99545865],
#        [19554.49741845],
#        [21709.77699147],
#        [21128.52481245],
#        [21965.59808625],
#        [21753.43665741],
#        [21606.67705746],
#        [20788.71584625],
#        [21460.09279753],
#        [20969.3160708 ],
#        [22903.66721379],
#        [20193.43646532],
#        [21833.21636825],
#        [21066.98046408],
#        [23502.27805517],
#        [21482.18564053],
#        [21247.75602866],
#        [19766.65884729],
#        [21096.96360816],
#        [23747.75408855],
#        [20843.24659366],
#        [21359.62296387],
#        [17737.27341138],
#        [21020.51535776],
#        [19755.43708577],
#        [21997.33463057],
#        [22191.43603696],
#        [21668.0460658 ],
#        [20247.61653268],
#        [21306.84561669],
#        [24087.38771472],
#        [20489.58576558],
#        [23057.96643477],
#        [21516.02626513],
#        [24520.65291363],
#        [21511.11674446],
#        [24082.30285403],
#        [22262.97476668],
#        [21536.54104792],
#        [20560.59847523],
#        [21729.94109421],
#        [17691.15898512],
#        [20954.5875088 ],
#        [22905.59595405],
#        [23868.56336497],
#        [21661.90916496],
#        [20373.33532977],
#        [20841.66853345],
#        [24299.19846352],
#        [20490.81314575],
#        [21977.87188792],
#        [21169.379038  ],
#        [22717.6314485 ],
#        [20974.57627152],
#        [23984.63846075],
#        [19451.22214441],
#        [20858.15049569],
#        [23468.43743057],
#        [21372.07210556],
#        [21032.78915943],
#        [21989.09364945],
#        [21824.27402704],
#        [21892.13061626],
#        [23786.67957384],
#        [21410.29623076],
#        [23490.53027358],
#        [21790.60874246],
#        [21083.98844639],
#        [20686.31727233],
#        [21180.4254595 ],
#        [21253.54224944],
#        [22087.81008287],
#        [23414.9587233 ],
#        [22463.21307391],
#        [21317.89203819],
#        [24268.33861933],
#        [23782.12073322],
#        [24862.03994004],
#        [20598.64726041],
#        [24027.77210662],
#        [21220.22764491],
#        [23514.90253689],
#        [20190.63102493],
#        [20648.96984725],
#        [24700.55177809],
#        [19334.27034851],
#        [24198.55328984],
#        [21865.65427266],
#        [21270.02421168],
#        [21320.8728186 ],
#        [20282.3338574 ],
#        [20819.2250104 ],
#        [19677.23543514],
#        [20214.47726818],
#        [21056.28472263],
#        [19826.80047547],
#        [20144.16591862],
#        [21057.86278284],
#        [22128.66430842],
#        [24526.43913442],
#        [21491.30332177],
#        [20951.08070832],
#        [20933.89738599],
#        [21101.34710875],
#        [20048.4302656 ],
#        [22386.58948349],
#        [22028.19447476],
#        [20469.94768291],
#        [22700.09744611],
#        [21399.07446923],
#        [21586.68829474],
#        [19876.07102217],
#        [21971.55964706],
#        [23901.70262948],
#        [20544.29185302],
#        [24003.92586338],
#        [19254.31529764],
#        [21800.77846384],
#        [21386.97600759],
#        [20277.77501678],
#        [20514.48404896],
#        [20769.9544637 ],
#        [20629.85778465],
#        [20719.28119681],
#        [19866.95334093],
#        [22868.24852897],
#        [22290.15247038],
#        [21063.12298356],
#        [22639.60513789],
#        [23271.5305838 ],
#        [22530.19296301],
#        [21141.32463419],
#        [23421.09562414],
#        [21906.68383824],
#        [19778.40662889],
#        [21494.63478222],
#        [22786.01405779],
#        [20579.35985778],
#        [21734.14925479],
#        [20603.7321211 ],
#        [21787.9786421 ],
#        [21940.52446284],
#        [19821.36493473],
#        [19515.57193316],
#        [20294.78299909]])

# %%
y_test
# Out:
#             Price
# 748  14881.955450
# 88   43374.052420
# 56   19981.127910
# 688  27256.494510
# 434  17986.224090
# ..            ...
# 731  29986.791500
# 336  13830.249020
# 169   9928.188175
# 618  14396.270560
# 367  17789.346730
#
# [201 rows x 1 columns]

# %%
from sklearn.metrics import mean_squared_error as mse
predict = lr.predict(x_test)
mse(y_test, predict)
# Out:
# 85706794.90954244
